# %%
#la fusion de la table dépasse plus d'un million de lignes donc on ne peut pas fusionner les données dans Microsoft Excel, il faut donc utiliser Python pour fusionner les fichiers Excel
# Feuille YEAR 2009_2010: 525 462 lignes
# Feuille YEAR 2010_2011: 541 911 lignes
! pip install pandas
# Out:
# Requirement already satisfied: pandas in C:\Users\solan\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=2.3.3 in C:\Users\solan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\solan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\solan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\solan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
# Fichier Excel
fichier = "online_retail.xlsx"

# Lire les deux feuilles
df1 = pd.read_excel(fichier, sheet_name="Year 2009-2010")
df2 = pd.read_excel(fichier, sheet_name="Year 2010-2011")

# Fusionner les deux tables
df = pd.concat([df1, df2], ignore_index=True)

# Enregistrer en CSV
df.to_csv("online_retail_fusionne.csv", index=False, encoding="utf-8-sig")

print(f"Fusion terminée : {len(df)} lignes")
# Out:
# Fusion terminée : 1067371 lignes

# %%
#maintenant on va requêter la table fusionnée avec DuckDB ( SQL) pour faire des analyses sur les données

# %%
# !pip install duckdb jupysql
# Out:
# Requirement already satisfied: duckdb in C:\Users\solan\AppData\Local\Programs\Python\Python314\Lib\site-packages (1.5.5)
# Collecting jupysql
#   Downloading jupysql-0.11.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting prettytable>=3.12.0 (from jupysql)
#   Downloading prettytable-3.18.0-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: sqlalchemy in C:\Users\solan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupysql) (2.0.52)
# Requirement already satisfied: sqlparse in C:\Users\solan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupysql) (0.5.5)
# Collecting ipython-genutils>=0.1.0 (from jupysql)
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl.metadata (755 bytes)
# Requirement already satisfied: jinja2 in C:\Users\solan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupysql) (3.1.6)
# Requirement already satisfied: sqlglot>=11.3.7 in C:\Users\solan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupysql) (30.17.0)
# Collecting jupysql-plugin>=0.4.2 (from jupysql)
#   Downloading jupysql_plugin-0.4.5-py3-none-any.whl.metadata (7.8 kB)
# Collecting ploomber-core>=0.2.7 (from jupysql)
#   Downloading ploomber_core-0.2.27-py3-none-any.whl.metadata (532 bytes)
# Requirement already satisfied: pyyaml in C:\Users\solan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ploomber-core>=0.2.7->jupysql) (6.0.2)
# Collecting posthog>=3.0 (from ploomber-core>=0.2.7->jupysql)
#   Downloading posthog-7.45.3-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: requests<3.0,>=2.7 in C:\Users\solan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.33.0)
# Collecting backoff>=1.10.0 (from posthog>=3.0->ploomber-core>=0.2.7->jupysql)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting distro>=1.5.0 (from posthog>=3.0->ploomber-core>=0.2.7->jupysql)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in C:\Users\solan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (4.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\solan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\solan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\solan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\solan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2025.1.31)
# Requirement already satisfied: wcwidth>=0.3.5 in C:\Users\solan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from prettytable>=3.12.0->jupysql) (0.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\solan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jinja2->jupysql) (3.0.3)
# Requirement already satisfied: greenlet>=1 in C:\Users\solan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sqlalchemy->jupysql) (3.5.5)
# Downloading jupysql-0.11.1-py3-none-any.whl (95 kB)
# Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Downloading jupysql_plugin-0.4.5-py3-none-any.whl (192 kB)
# Downloading ploomber_core-0.2.27-py3-none-any.whl (22 kB)
# Downloading posthog-7.45.3-py3-none-any.whl (598 kB)
#    ---------------------------------------- 0.0/598.4 kB ? eta -:--:--
#    ---------------------------------------- 598.4/598.4 kB 15.7 MB/s  0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading prettytable-3.18.0-py3-none-any.whl (37 kB)
# Installing collected packages: ipython-genutils, prettytable, distro, backoff, posthog, ploomber-core, jupysql-plugin, jupysql
#
#    ----- ---------------------------------- 1/8 [prettytable]
#    -------------------- ------------------- 4/8 [posthog]
#    -------------------- ------------------- 4/8 [posthog]
#    -------------------- ------------------- 4/8 [posthog]
#    -------------------- ------------------- 4/8 [posthog]
#    -------------------- ------------------- 4/8 [posthog]
#    -------------------- ------------------- 4/8 [posthog]
#    -------------------- ------------------- 4/8 [posthog]
#    -------------------- ------------------- 4/8 [posthog]
#    ------------------------- -------------- 5/8 [ploomber-core]
#    ----------------------------------- ---- 7/8 [jupysql]
#    ----------------------------------- ---- 7/8 [jupysql]
#    ---------------------------------------- 8/8 [jupysql]
#
# Successfully installed backoff-2.2.1 distro-1.9.0 ipython-genutils-0.2.0 jupysql-0.11.1 jupysql-plugin-0.4.5 ploomber-core-0.2.27 posthog-7.45.3 prettytable-3.18.0
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %load_ext sql

# %sql duckdb:///online_retail.duckdb
# Out:
# Connecting to 'duckdb:///online_retail.duckdb'

# %%
#créer une table dans DuckDB à partir du fichier CSV fusionné

# %%
CREATE OR REPLACE TABLE online_retail AS
SELECT *
FROM read_csv_auto('online_retail_fusionne.csv');
# Out:
# Running query in 'duckdb:///online_retail.duckdb'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
SELECT * 
FROM online_retail
LIMIT 5;
# Out:
# Running query in 'duckdb:///online_retail.duckdb'
# +---------+-----------+-------------------------------------+----------+---------------------+-------+-------------+----------------+
# | Invoice | StockCode |             Description             | Quantity |     InvoiceDate     | Price | Customer ID |    Country     |
# +---------+-----------+-------------------------------------+----------+---------------------+-------+-------------+----------------+
# |  489434 |   85048   | 15CM CHRISTMAS GLASS BALL 20 LIGHTS |    12    | 2009-12-01 07:45:00 |  6.95 |   13085.0   | United Kingdom |
# |  489434 |   79323P  |          PINK CHERRY LIGHTS         |    12    | 2009-12-01 07:45:00 |  6.75 |   13085.0   | United Kingdom |
# |  489434 |   79323W  |          WHITE CHERRY LIGHTS        |    12    | 2009-12-01 07:45:00 |  6.75 |   13085.0   | United Kingdom |
# |  489434 |   22041   |     RECORD FRAME 7" SINGLE SIZE     |    48    | 2009-12-01 07:45:00 |  2.1  |   13085.0   | United Kingdom |
# |  489434 |   21232   |    STRAWBERRY CERAMIC TRINKET BOX   |    24    | 2009-12-01 07:45:00 |  1.25 |   13085.0   | United Kingdom |
# +---------+-----------+-------------------------------------+----------+---------------------+-------+-------------+----------------+
